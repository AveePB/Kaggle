# %% [markdown]
# ## House Pricing - Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import scipy.stats as stats
from IPython.display import display, HTML

# %% [markdown]
# ### Basic Data Exploration

# %%
df = pd.read_csv("./data/train.csv")

# %%
def get_scrollable_table(df, title):
    # Wrap the HTML in a <div> with overflow properties
    scrollable_html = f"""
    <h3>{title}</h3>
    <div style="overflow:auto; height:400px; width:100%;">
        {df.to_html()}
    </div>
    """
    # Display the HTML
    return HTML(scrollable_html)

# %%
numerical_features = df.select_dtypes(include=[np.number])
summary_stats = numerical_features.describe().T
html_numerical = get_scrollable_table(summary_stats, "Summary statistics for numerical features")

display(html_numerical)
print(df.shape)
# Out:
#     <h3>Summary statistics for numerical features</h3>
#     <div style="overflow:auto; height:400px; width:100%;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Id</th>
#       <td>1460.0</td>
#       <td>730.500000</td>
#       <td>421.610009</td>
#       <td>1.0</td>
#       <td>365.75</td>
#       <td>730.5</td>
#       <td>1095.25</td>
#       <td>1460.0</td>
#     </tr>
#     <tr>
#       <th>MSSubClass</th>
#       <td>1460.0</td>
#       <td>56.897260</td>
#       <td>42.300571</td>
#       <td>20.0</td>
#       <td>20.00</td>
#       <td>50.0</td>
#       <td>70.00</td>
#       <td>190.0</td>
#     </tr>
#     <tr>
#       <th>LotFrontage</th>
#       <td>1201.0</td>
# ...

# %%
categorical_features = df.select_dtypes(include=[object])
cat_summary_stats = categorical_features.describe().T
html_categorical = get_scrollable_table(cat_summary_stats, "Summary statistics for categorical features")

display(html_categorical)
print(df.shape)
# Out:
#     <h3>Summary statistics for categorical features</h3>
#     <div style="overflow:auto; height:400px; width:100%;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MSZoning</th>
#       <td>1460</td>
#       <td>5</td>
#       <td>RL</td>
#       <td>1151</td>
#     </tr>
#     <tr>
#       <th>Street</th>
#       <td>1460</td>
#       <td>2</td>
#       <td>Pave</td>
#       <td>1454</td>
#     </tr>
#     <tr>
#       <th>Alley</th>
#       <td>91</td>
#       <td>2</td>
#       <td>Grvl</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>LotShape</th>
#       <td>1460</td>
#       <td>4</td>
#       <td>Reg</td>
#       <td>925</td>
#     </tr>
#     <tr>
#       <th>LandContour</th>
#       <td>1460</td>
#       <td>4</td>
#       <td>Lvl</td>
# ...

# %%
null_vals = df.isna().sum()
html_null_vals = get_scrollable_table(null_vals.to_frame(), "NaN values in the dataset")

display(html_null_vals)
print(df.shape)
# Out:
#     <h3>NaN values in the dataset</h3>
#     <div style="overflow:auto; height:400px; width:100%;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>MSSubClass</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>MSZoning</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>LotFrontage</th>
#       <td>259</td>
#     </tr>
#     <tr>
#       <th>LotArea</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Street</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Alley</th>
#       <td>1369</td>
#     </tr>
#     <tr>
#       <th>LotShape</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>LandContour</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Utilities</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>LotConfig</th>
# ...

# %%
null_precentage = (df.isnull().sum() / len(df)) * 100
html_null_precentage = get_scrollable_table(null_precentage.to_frame(), "Precentage of NaNs in the dataset")

display(html_null_precentage)
print(df.shape)
# Out:
#     <h3>Precentage of NaNs in the dataset</h3>
#     <div style="overflow:auto; height:400px; width:100%;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Id</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>MSSubClass</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>MSZoning</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>LotFrontage</th>
#       <td>17.739726</td>
#     </tr>
#     <tr>
#       <th>LotArea</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Street</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Alley</th>
#       <td>93.767123</td>
#     </tr>
#     <tr>
#       <th>LotShape</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>LandContour</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Utilities</th>
# ...

# %%
rows_with_null_values = df[df.isnull().any(axis=1)]
html_rows_with_null_values = get_scrollable_table(rows_with_null_values, "Rows with NaNs")

display(html_rows_with_null_values)
print(df.shape)
# Out:
#     <h3>Rows with NaNs</h3>
#     <div style="overflow:auto; height:400px; width:100%;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotFrontage</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>Alley</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>LotConfig</th>
#       <th>LandSlope</th>
#       <th>Neighborhood</th>
#       <th>Condition1</th>
#       <th>Condition2</th>
#       <th>BldgType</th>
#       <th>HouseStyle</th>
#       <th>OverallQual</th>
#       <th>OverallCond</th>
#       <th>YearBuilt</th>
#       <th>YearRemodAdd</th>
#       <th>RoofStyle</th>
#       <th>RoofMatl</th>
#       <th>Exterior1st</th>
#       <th>Exterior2nd</th>
#       <th>MasVnrType</th>
#       <th>MasVnrArea</th>
#       <th>ExterQual</th>
#       <th>ExterCond</th>
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ### Exploration of the dependent variable

# %%
df['SalePrice'].isna().sum()
# Out:
# 0

# %%
df['SalePrice'].mean()
# Out:
# 180921.19589041095

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['SalePrice'], bins=20, kde=True)
plt.title('Distribution of House Sale Prices')
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Starting cleaning process

# %%
def pretty_histogram(values, names, *, xlabel="Bins", ylablel="Values", title="Histogram"):
    fig, ax = plt.subplots(figsize=(10, 6))

    # Calculate number of bins
    num_bins = len(values)

    # Plot histogram with bars
    bars = ax.bar(range(num_bins), values, tick_label=names, color='skyblue')

    # Add values on top of each bar
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval + 0.1, round(yval, 2), ha='center', va='bottom')

    # Labeling and title
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylablel)
    ax.set_title(title)

    # Show plot
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Preprocessing numerical features

# %%
# LotFrontage
plt.scatter(df["LotFrontage"], df["SalePrice"])
plt.xlabel("LotFrontage")
plt.ylabel("Sale Price")
plt.title("LotFrontage & Sale Prices")
plt.show()

# %%
# LotArea
plt.scatter(df["LotArea"], df["SalePrice"])
plt.xlabel("LotArea")
plt.ylabel("Sale Price")
plt.title("LotArea & Sale Prices")
plt.show()

# %% [markdown]
# #### Preprocessing categorical features

# %%
# MSSubClass
UNIQUE_VALS = np.unique(df["MSSubClass"].values)
means = []

for val in UNIQUE_VALS:
    means.append(df.loc[df["MSSubClass"] == val, "SalePrice"].mean())
means = np.array(means)

# %%
pretty_histogram(means, UNIQUE_VALS, xlabel="MSSubClass", ylablel="Avg. Sale Price", title="MSSubClass & Sale Prices")

# %%
#MSZoning
UNIQUE_VALS = np.unique(df["MSZoning"].values)
means = []

for val in UNIQUE_VALS:
    means.append(df.loc[df["MSZoning"] == val, "SalePrice"].mean())
means = np.array(means)

# %%
pretty_histogram(means, UNIQUE_VALS, xlabel="MSZoning", ylablel="Avg. Sale Price", title="MSZoning & Sale Prices")

# %%
# Street
UNIQUE_VALS = np.unique(df["Street"].values)
means = []

for val in UNIQUE_VALS:
    means.append(df.loc[df["Street"] == val, "SalePrice"].mean())
means = np.array(means)

# %%
pretty_histogram(means, UNIQUE_VALS, xlabel="Street", ylablel="Avg. Sale Price", title="Street & Sale Prices")

# %%
# Alley

# %% [markdown]
# ### Saving data

# %%
df.to_csv("./data/clean_train.csv")
